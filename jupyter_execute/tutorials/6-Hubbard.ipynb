# %% [markdown]
# This tutorial is about
# - Define fermion systems
# - Use determinant to learn fermion ground states

# %%
import numpy as np
import matplotlib.pyplot as plt
import jax.numpy as jnp
import quantax as qtx

lattice = qtx.sites.Square(
    4, Nparticle=(4, 4), particle_type=qtx.PARTICLE_TYPE.spinful_fermion
)  # fermion lattice
N = lattice.N
# Out:
# WARNING:2025-08-22 13:55:30,287:jax._src.xla_bridge:794: An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %%
# Hubbard model
H = qtx.operator.Hubbard(U=4)

# determinant with 8 electrons
model = qtx.model.Determinant()

state = qtx.state.Variational(
    model,
    max_parallel=10000, # maximum forward batch on each machine
)

# new samples proposed by electron hopping
sampler = qtx.sampler.ParticleHop(state, 1000)
optimizer = qtx.optimizer.SR(state, H)

# %%
energy_data = qtx.utils.DataTracer()
VarE_data = qtx.utils.DataTracer()

for i in range(200):
    samples = sampler.sweep()
    step = optimizer.get_step(samples)
    state.update(step * 0.01)
    energy_data.append(optimizer.energy)
    VarE_data.append(optimizer.VarE)

energy_data.plot()
plt.show()
VarE_data.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 7
#       5 samples = sampler.sweep()
#       6 step = tdvp.get_step(samples)
# ----> 7 state.update(step * 0.01)
#       8 energy_data.append(tdvp.energy)
#       9 VarE_data.append(tdvp.VarE)
#
# File ~/quantax_env/lib/python3.12/site-packages/quantax/state/variational.py:509, in Variational.update(self, step, rescale)
#     493 def update(self, step: jax.Array, rescale: bool = True) -> None:
#     494     r"""
#     495     Update the variational parameters of the state as
#     496     :math:`\theta' = \theta - \delta\theta`.
#    (...)    507         The update direction is :math:`-\delta\theta` instead of :math:`\delta\theta`.
#     508     """
# --> 509     if not jnp.all(jnp.isfinite(step)):
#     510         warn("Got invalid update step. The update is interrupted.")
#     511         return
#
# File ~/quantax_env/lib/python3.12/site-packages/jax/_src/array.py:306, in ArrayImpl.__bool__(self)
#     304 def __bool__(self):
#     305   core.check_bool_conversion(self)
# --> 306   return bool(self._value)
#
# File ~/quantax_env/lib/python3.12/site-packages/jax/_src/profiler.py:354, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     351 @wraps(func)
#     352 def wrapper(*args, **kwargs):
#     353   with TraceAnnotation(name, **decorator_kwargs):
# --> 354     return func(*args, **kwargs)
#
# File ~/quantax_env/lib/python3.12/site-packages/jax/_src/array.py:644, in ArrayImpl._value(self)
#     641 if self._npy_value is None:
#     642   if (self.is_fully_replicated and
#     643       self.sharding._internal_device_list.addressable_device_list):  # type: ignore
# --> 644     npy_value, did_copy = self._single_device_array_to_np_array_did_copy()
#     645     npy_value.flags.writeable = False
#     646     if did_copy:
#
# KeyboardInterrupt:

# %%
# symmetrize the trained NQS
# The ground state sector is in the B1 representation
from quantax.symmetry import SpinInverse, C4v, Trans2D


symm = Trans2D() + SpinInverse() + C4v("B1")
H = qtx.operator.Hubbard(U=4)

symm_state = qtx.state.Variational(
    state.model,
    symm=symm,
    max_parallel=32768,
)

sampler = qtx.sampler.ParticleHop(symm_state, 1000)
optimizer = qtx.optimizer.SR(symm_state, H)

# %%
energy_data = qtx.utils.DataTracer()
VarE_data = qtx.utils.DataTracer()

for i in range(100):
    samples = sampler.sweep()
    step = optimizer.get_step(samples)
    symm_state.update(step * 0.01)
    energy_data.append(optimizer.energy)
    VarE_data.append(optimizer.VarE)

energy_data.plot()
plt.show()
VarE_data.plot()
plt.show()

# %%
# check result by ED
E, wf = H.diagonalize(symm)
print(E[0])
# Out:
# /home/chenao/quantax_env/lib/python3.12/site-packages/quantax/symmetry/symmetry.py:299: GeneralBasisWarning: using non-commuting symmetries can lead to unwanted behaviour of general basis, make sure that quantum numbers are invariant under non-commuting symmetries!
#   self.basis.make()
# -17.5348977966412
