# %% [markdown]
# This tutorial is about
# - Global constants in quantax
# - Define Symmetry
# - Define Ising Hamiltonian
# - Exact diagonalization
# - Define RBM neural quantum state
# - Exact reconfiguration
# - Stochastic reconfiguration (TDVP)

# %%
import numpy as np
import jax.numpy as jnp
import quantax as qtx

# ======================= Global constants in quantax =======================
# random seed, default to 0
qtx.set_random_seed(2347)

# default data types for computations outside variational ansatz, default to float64
qtx.set_default_dtype(jnp.float64)

# lattice of quantum systems, MUST be given in the beginning of the program
# lattice is treated as a GLOBAL CONSTANT implicitly passed to other quantities
# DON'T define different lattices in a single run
lattice = qtx.sites.Chain(12) # default to periodic boundaries
# Out:
# WARNING:2025-08-22 13:54:34,596:jax._src.xla_bridge:794: An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %%
# Ising hamiltonian with transverse field h=1
H = qtx.operator.Ising(h=1)

# an alternative way to define the Ising hamiltonian

from quantax.operator import sigma_z, sigma_x

L = lattice.N
h = 1
# periodic boundary is assumed
H = -sum(sigma_z(i) * sigma_z(i+1) for i in range(L))
H -= sum(h * sigma_x(i) for i in range(L))

# %%
from quantax.symmetry import Trans1D, SpinInverse, Flip

# combination of symmetries can be done by a summation
symm = Trans1D() + SpinInverse() + Flip()

# diagonalize H in the given symmetry sector and obtain the 3 lowest eigenstates
E, wave_function = H.diagonalize(symm=symm, k=3)
print(E)

# construct a dense state given the ground state wave function
dense = qtx.state.DenseState(wave_function[:, 0], symm=symm)

# compute <dense|H|dense>, verify the ground state energy
energy = dense @ H @ dense
assert np.isclose(energy, E[0])

# `GeneralBasisWarning` is because Trans1D and Flip don't commute with each other.
# Out:
# /home/aochen/quantax_env/lib/python3.12/site-packages/quantax/symmetry/symmetry.py:268: GeneralBasisWarning: using non-commuting symmetries can lead to unwanted behaviour of general basis, make sure that quantum numbers are invariant under non-commuting symmetries!
#   basis = spin_basis_general(self.N, Nup, pauli=0, make_basis=False, **blocks)
# [-15.32259515 -14.27838561 -12.26112769]

# %%
# RBM wave function with alpha=4
model = qtx.model.RBM_Dense(features=4*L)

# define the variational state with given symmetry projection
state = qtx.state.Variational(model=model, symm=symm)

# define exact reconfiguration optimizer
# this is only for tests in small systems where the full wave function can be obtained
optimizer = qtx.optimizer.ER(state, H, symm=symm)

# %%
# a data tracer for recording the energy
energy_data = qtx.utils.DataTracer()

# optimization iterations
for i in range(100):
    step = optimizer.get_step()
    state.update(step * 1e-2) # step size 1e-2
    energy_data.append(optimizer.energy)

energy_data.plot(baseline=E[0])

# %%
# variational energies can also be computed exactly in small systems

state_dense = state.todense(symm).normalize()
# E = <psi|H|psi>
variational_energy = state_dense @ H @ state_dense
print(variational_energy)
# Out:
# -15.222630995887238

# %%
# define a new variational state
model = qtx.model.RBM_Dense(features=4*L)
state = qtx.state.Variational(model=model, symm=symm)

# sampler with local flip updates
sampler = qtx.sampler.LocalFlip(state, nsamples=1000)

# stochastic reconfiguration optimizer, which can work in most cases
optimizer = qtx.optimizer.SR(state, H)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       3 state = qtx.state.Variational(model=model, symm=symm)
#       5 # sampler with local flip updates
# ----> 6 sampler = qtx.sampler.LocalFlip(state, nsamples=1000)
#       8 # stochastic reconfiguration optimizer, which can work in most cases
#       9 optimizer = qtx.optimizer.SR(state, H)
#
# File ~/quantax_env/lib/python3.12/site-packages/quantax/sampler/metropolis.py:88, in Metropolis.__init__(self, state, nsamples, reweight, thermal_steps, sweep_steps, initial_spins)
#      85 self._particle_type = sites.particle_type
#      86 self._double_occ = sites.double_occ
# ---> 88 self.reset()
#
# File ~/quantax_env/lib/python3.12/site-packages/quantax/sampler/metropolis.py:115, in Metropolis.reset(self)
#     112     self._spins = self._initial_spins
#     114 if self._thermal_steps > 0:
# --> 115     self.sweep(self._thermal_steps)
#
# File ~/quantax_env/lib/python3.12/site-packages/quantax/sampler/metropolis.py:136, in Metropolis.sweep(self, nsweeps)
#     133 else:
#     134     fn_sweep = self._partial_sweep
# --> 136 samples = fn_sweep(nsweeps, self._spins)
#     138 self._spins = samples.spins
#     139 if isinstance(self._state, Variational):
#
# File ~/quantax_env/lib/python3.12/site-packages/quantax/sampler/metropolis.py:156, in Metropolis._partial_sweep(self, nsweeps, spins)
#     154 keys_update = to_replicate_array(get_subkeys(nsweeps))
#     155 for keyp, keyu in zip(keys_propose, keys_update):
# --> 156     samples = self._single_sweep(keyp, keyu, samples)
#     158 if samples.state_internal is not None:
#     159     samples = eqx.tree_at(lambda tree: tree.state_internal, samples, None)
#
# File ~/quantax_env/lib/python3.12/site-packages/quantax/sampler/metropolis.py:180, in Metropolis._single_sweep(self, keyp, keyu, samples)
#     178     state_internal = None
#     179 else:
# --> 180     new_wf, state_internal = self._state.ref_forward_with_updates(
#     181         new_spins, samples.spins, self.nflips, samples.state_internal
#     182     )
#     183 new_samples = Samples(new_spins, new_wf, state_internal=state_internal)
#     184 samples = self._update(keyu, propose_ratio, samples, new_samples)
#
# File ~/quantax_env/lib/python3.12/site-packages/quantax/state/variational.py:334, in Variational.ref_forward_with_updates(self, s, s_old, nflips, internal)
#     331 if not isinstance(self.model, RefModel):
#     332     return self(s), None
# --> 334 return self._ref_forward_with_updates(self.model, s, s_old, nflips, internal)
#
#     [... skipping hidden 38 frame]
#
# File ~/quantax_env/lib/python3.12/site-packages/quantax/state/variational.py:265, in Variational._init_forward.<locals>.ref_forward_with_updates(model, s, s_old, nflips, internal)
#     263 forward = partial(model.ref_forward, return_update=True)
#     264 forward = eqx.filter_vmap(forward, in_axes=(0, 0, None, 0))
# --> 265 psi, internal = forward(s_symm, s_old_symm, nflips, internal)
#     266 psi *= jax.vmap(self._factor)(s_symm)
#     267 psi = self.symm.symmetrize(psi, s)
#
#     [... skipping hidden 9 frame]
#
# File ~/quantax_env/lib/python3.12/site-packages/equinox/_module.py:1060, in BoundMethod.__call__(self, *args, **kwargs)
#    1058 def __call__(self, *args, **kwargs):
#    1059     __tracebackhide__ = True
# -> 1060     return self.__func__(self.__self__, *args, **kwargs)
#
# TypeError: SingleDense.ref_forward() got an unexpected keyword argument 'return_update'

# %%
energy_data = qtx.utils.DataTracer()

# optimization iterations, now requires sampling
for i in range(100):
    samples = sampler.sweep()
    step = optimizer.get_step(samples)
    state.update(step * 1e-2)
    energy_data.append(optimizer.energy)

energy_data.plot(baseline=E[0])
