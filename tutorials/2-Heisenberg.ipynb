# %% [markdown]
# This tutorial is about
# - Define Heisenberg Hamiltonian
# - Define CNN neural quantum state
# - Symmetrize wave functions

# %%
import numpy as np
import matplotlib.pyplot as plt
import jax.numpy as jnp
import quantax as qtx

# 4x4 square lattice, 8 spin-up, 8 spin-down
lattice = qtx.sites.Square(4, Nparticle=(8, 8))
N = lattice.N

# %%
from quantax.symmetry import SpinInverse, C4v, Trans2D

# Heisenberg model with Marshall sign rule, default to nearest neighbor
# The lattice is implicitly passed as a global constant
H = qtx.operator.Heisenberg(msr=True)

# residual convolutional network with a summation for the final output
# 2 blocks, 8 channels and 4x4 kernels
net = qtx.model.ResSum(2, 8, 4)

state = qtx.state.Variational(
    net,
    max_parallel=32768,  # maximum forward batch on each machine
)

# import warnings
# with warnings.catch_warnings():
#     warnings.simplefilter('error')

sampler = qtx.sampler.SpinExchange(state, 1000)
optimizer = qtx.optimizer.SR(state, H)

# %%
energy_data = qtx.utils.DataTracer()
VarE_data = qtx.utils.DataTracer()

for i in range(200):
    samples = sampler.sweep()
    step = optimizer.get_step(samples)
    state.update(step * 1e-3)
    energy_data.append(optimizer.energy)
    VarE_data.append(optimizer.VarE)

energy_data.plot()
plt.show()
VarE_data.plot()
plt.show()
# Out:
# Could not load symbol cuFuncGetName. Error: /lib/x86_64-linux-gnu/libcuda.so.1: undefined symbol: cuFuncGetName
# 2025-08-08 14:34:23.705365: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:23.858922: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:24.011509: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:24.211131: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:24.380906: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:24.680895: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:24.836424: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:24.993776: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:25.151407: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:25.307703: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:25.519423: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:25.697989: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.

# %% [markdown]
# Symmetrized NQS can provide much better performance
#
# $\psi_\mathrm{symm}(s) = \frac{1}{|G|} \sum_g \omega_g^{-1} \psi(T_g s)$
#
# for a symmetry group $\{g\}$ of order $|G|$ represented by operators $T_g$ with
# characters $\omega_g$

# %%
# symmetrize the trained NQS

# no need to include translational symmetry, because it's encoded in CNN architecture
symm = SpinInverse() + C4v()

# Symmetrization method 1
symm_state = qtx.state.Variational(
    state.model,  # the trained network
    symm=symm,  # specify symmetry
    max_parallel=32768,
)

# Symmetrization method 2
state.save("/tmp/Heisenberg_params.eqx")  # save as an equinox weight file
net = qtx.model.ResSum(2, 8, 4)  # the same network
symm_state = qtx.state.Variational(
    net,
    param_file="/tmp/Heisenberg_params.eqx",  # load weights
    symm=symm,  # specify symmetry
    max_parallel=32768,
)

sampler = qtx.sampler.SpinExchange(symm_state, 1000)
optimizer = qtx.optimizer.SR(symm_state, H)

# %%
energy_data = qtx.utils.DataTracer()
VarE_data = qtx.utils.DataTracer()

for i in range(200):
    samples = sampler.sweep()
    step = optimizer.get_step(samples)
    symm_state.update(step * 1e-3)
    energy_data.append(optimizer.energy)
    VarE_data.append(optimizer.VarE)

energy_data.plot()
plt.show()
VarE_data.plot()
plt.show()
# Out:
# 2025-08-08 14:34:50.153165: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:50.325388: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:50.645829: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:50.863371: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:51.084543: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:51.297886: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:51.629494: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:51.853291: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:52.073805: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:52.401005: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:52.620033: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:52.861625: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:53.034659: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:53.353733: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:53.569412: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:53.898430: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:54.122115: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:54.452092: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:54.673379: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:55.612885: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:55.676021: E external/xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng3{k11=0} for conv (f32[8,128000,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,16000,7,7]{3,2,1,0}, f32[128000,1,4,4]{3,2,1,0}), window={size=4x4}, dim_labels=bf01_oi01->bf01, feature_group_count=16000, operand_precision={highest,highest}, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-08-08 14:34:56.140064: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:56.145968: E external/xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.470040207s
# Trying algorithm eng3{k11=0} for conv (f32[8,128000,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,16000,7,7]{3,2,1,0}, f32[128000,1,4,4]{3,2,1,0}), window={size=4x4}, dim_labels=bf01_oi01->bf01, feature_group_count=16000, operand_precision={highest,highest}, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-08-08 14:34:57.146103: E external/xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng4{} for conv (f32[8,128000,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,16000,7,7]{3,2,1,0}, f32[128000,1,4,4]{3,2,1,0}), window={size=4x4}, dim_labels=bf01_oi01->bf01, feature_group_count=16000, operand_precision={highest,highest}, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-08-08 14:34:57.485218: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:58.217604: E external/xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-08-08 14:34:58.230341: E external/xla/xla/service/slow_operation_alarm.cc:140] The operation took 2.084317219s
# Trying algorithm eng4{} for conv (f32[8,128000,4,4]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,16000,7,7]{3,2,1,0}, f32[128000,1,4,4]{3,2,1,0}), window={size=4x4}, dim_labels=bf01_oi01->bf01, feature_group_count=16000, operand_precision={highest,highest}, custom_call_target="__cudnn$convForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...

# %%
# check result by ED
full_symm = symm + Trans2D()
E, wf = H.diagonalize(full_symm)
print(E[0])

# `GeneralBasisWarning` is because C4v and Trans2D don't commute with each other
# Out:
# /home/aochen/quantax_env/lib/python3.12/site-packages/quantax/symmetry/symmetry.py:268: GeneralBasisWarning: using non-commuting symmetries can lead to unwanted behaviour of general basis, make sure that quantum numbers are invariant under non-commuting symmetries!
#   basis = spin_basis_general(self.N, Nup, pauli=0, make_basis=False, **blocks)
# -44.91393283371544
